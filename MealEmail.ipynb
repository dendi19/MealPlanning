# %%
import pandas as pd
import random
from datetime import date
import datetime

today = date.today()

# %%
thisweekdf = pd.read_csv("thisweeksmeals.csv")
df = pd.read_csv("allmeals.csv")

# %%
count = 1 

for days,meals in thisweekdf.iterrows():
    print(meals)
  ##Monday
    if datetime.datetime.today().weekday() == 0:
        for schedule, recipe in df.iterrows():
            if meals[3] == recipe[0] and count == 1:
                print(f"Tuesday's For breakfast you are making:\n{meals[3]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                breakfast = meals[3]
                breakfastrecipe = recipe[2]
                b_inst = recipe[4]
            elif meals[3] == recipe[0] and count == 2:
                print(f"Tuesday's For lunch you are making:\n{meals[3]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                lunch = meals[3]
                lunchrecipe = recipe[2]
                l_inst = recipe[4]
            elif meals[3] == recipe[0] and count == 3:
                print(f"Tuesday's For Dinner you are making:\n{meals[3]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                dinner = meals[3]
                dinnerrecipe = recipe[2]
                d_inst = recipe[4]
  ##Tuesday
    elif datetime.datetime.today().weekday() == 1:
        for schedule, recipe in df.iterrows():
            if meals[4] == recipe[0] and count == 1:
                print(f"Wednesday's For breakfast you are making:\n{meals[4]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                breakfast = meals[4]
                breakfastrecipe = recipe[2]
                b_inst = recipe[4]
            elif meals[4] == recipe[0] and count == 2:
                print(f"Wednesday's For lunch you are making:\n{meals[4]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                lunch = meals[4]
                lunchrecipe = recipe[2]
                l_inst = recipe[4]
            elif meals[4] == recipe[0] and count == 3:
                print(f"Wednesday's For Dinner you are making:\n{meals[4]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                dinner = meals[4]
                dinnerrecipe = recipe[2]
                d_inst = recipe[4]
            #print(count)
  ##Wednesday
    elif datetime.datetime.today().weekday() == 2:
        for schedule, recipe in df.iterrows():
            if meals[5] == recipe[0] and count == 1:
                print(f"Thursday's For breakfast you are making:\n{meals[5]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                breakfast = meals[5]
                breakfastrecipe = recipe[2]
                b_inst = recipe[4]
            elif meals[5] == recipe[0] and count == 2:
                print(f"Thursday's For lunch you are making:\n{meals[5]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                lunch = meals[5]
                lunchrecipe = recipe[2]
                l_inst = recipe[4]
            elif meals[5] == recipe[0] and count == 3:
                print(f"Thursday's For Dinner you are making:\n{meals[5]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                dinner = meals[5]
                dinnerrecipe = recipe[2]
                d_inst = recipe[4]
  ##Thursday
    elif datetime.datetime.today().weekday() == 3:
        for schedule, recipe in df.iterrows():
            if meals[6] == recipe[0] and count == 1:
                print(f"Friday's For breakfast you are making:\n{meals[6]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                breakfast = meals[6]
                breakfastrecipe = recipe[2]
                b_inst = recipe[4]
            elif meals[6] == recipe[0] and count == 2:
                print(f"Friday's For lunch you are making:\n{meals[6]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                lunch = meals[6]
                lunchrecipe = recipe[2]
                l_inst = recipe[4]
            elif meals[6] == recipe[0] and count == 3:
                print(f"Friday's For Dinner you are making:\n{meals[6]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                dinner = meals[6]
                dinnerrecipe = recipe[2]
                d_inst = recipe[4]
  ##Friday
    elif datetime.datetime.today().weekday() == 4:
        for schedule, recipe in df.iterrows():
            if meals[7] == recipe[0] and count == 1:
                print(f"Saturday's For breakfast you are making:\n{meals[7]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                breakfast = meals[7]
                breakfastrecipe = recipe[2]
                b_inst = recipe[4]
            elif meals[7] == recipe[0] and count == 2:
                print(f"Saturday's For lunch you are making:\n{meals[7]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                lunch = meals[7]
                lunchrecipe = recipe[2]
                l_inst = recipe[4]
            elif meals[7] == recipe[0] and count == 3:
                print(f"Saturday's For Dinner you are making:\n{meals[7]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                dinner = meals[7]
                dinnerrecipe = recipe[2]
                d_inst = recipe[4]
  ##Saturday
    elif datetime.datetime.today().weekday() == 5:
        for schedule, recipe in df.iterrows():
            if meals[1] == recipe[0] and count == 1:
                print(f"Sunday's For breakfast you are making:\n{meals[1]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                breakfast = meals[1]
                breakfastrecipe = recipe[2]
                b_inst = recipe[4]
            elif meals[1] == recipe[0] and count == 2:
                print(f"Sunday's For lunch you are making:\n{meals[1]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                lunch = meals[1]
                lunchrecipe = recipe[2]
                l_inst = recipe[4]
            elif meals[1] == recipe[0] and count == 3:
                print(f"Sunday's For Dinner you are making:\n{meals[1]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                dinner = meals[1]
                dinnerrecipe = recipe[2]
                d_inst = recipe[4]
  ##Sunday
    elif datetime.datetime.today().weekday() == 6:
        for schedule, recipe in df.iterrows():
            if meals[2] == recipe[0] and count == 1:
                print(f"Monday's For breakfast you are making:\n{meals[2]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                breakfast = meals[2]
                breakfastrecipe = recipe[2]
                b_inst = recipe[4]
            elif meals[2] == recipe[0] and count == 2:
                print(f"Monday's For lunch you are making:\n{meals[2]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                lunch = meals[2]
                lunchrecipe = recipe[2]
                l_inst = recipe[4]
            elif meals[2] == recipe[0] and count == 3:
                print(f"Monday's For Dinner you are making:\n{meals[2]} \n\nThis requres: \n{recipe[2]}\n\n\n")
                dinner = meals[2]
                dinnerrecipe = recipe[2]
                d_inst = recipe[4]
    count = count +1
# Out:
# Unnamed: 0                                       0
# Meal                                     Breakfast
# Sunday                           Mini Egg Fritatas
# Monday        Mediteranean Avocado Toast with eggs
# Tuesday                          Mini Egg Fritatas
# Wednesday                        Mini Egg Fritatas
# Thursday          Blueberry Lemon Ricotta Pancakes
# Friday        Eggs Poached in Curried Tomato Sauce
# Saturday                  Whole-Grain Bran Muffins
# Name: 0, dtype: object
# Wednesday's For breakfast you are making:
# Mini Egg Fritatas
#
# This requres:
# 3 eggs <br>
# 2oz sauteed vegetables (chefs choice)  <br>
# protein (optional)
#
#
#
# Unnamed: 0                                                    1
# Meal                                                      Lunch
# Sunday                          Grilled Lemon Chicken Flatbread
# Monday                                                 BLT Cups
# ...

# %%
print(f"Tomorrow's Meals: \n\nBreakfast: {breakfast} \n{b_inst} \n\nLunch: {lunch} \n{l_inst}\n\nDinner: {dinner} \n{d_inst}")

web = f"{b_inst}"
##meal = f"'{breakfast}'"

print(f'<a href="{web}">{breakfast}</a>')
# Out:
# Tomorrow's Meals:
#
# Breakfast: Mini Egg Fritatas
# https://www.womenshealthmag.com/weight-loss/a19993913/protein-breakfast-ideas/
#
# Lunch: Thai Chicken Lettuce Cups
# https://www.delish.com/cooking/recipe-ideas/recipes/a57645/thai-chicken-lettuce-cups-recipe/
#
# Dinner: Cajun Stuffed Chicken
# https://www.delish.com/cooking/recipe-ideas/recipes/a55535/healthy-cajun-stuffed-chicken-recipe/
# <a href="https://www.womenshealthmag.com/weight-loss/a19993913/protein-breakfast-ideas/">Mini Egg Fritatas</a>

# %%
#####Rows


import smtplib
from email.message import EmailMessage

#####TESTAREA########
import smtplib, ssl
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

sender_email = "m.dendinger19@gmail.com"
receiver_email = "m.dendinger19@gmail.com"

message = MIMEMultipart("alternative")
message["Subject"] = "Tomorrow's Meals"
message["From"] = "m.dendinger19@gmail.com"
message["To"] = "m.dendinger19@gmail.com"

box = '{box-sizing: border-box;}'
columned = '{float: left;}'
lefts = '{width: 33%;}'
middles = '{width: 33%;}'
rights = '{width: 33%;}'
rowafter = '{content: ""; display: table; clear: both;}'


html = f"""\
<html>
  <head>
    <style>
    {box}
    .column {columned}
    .left{lefts}
    .middle{middles}
    .right{rights}
    .row:after {rowafter}
    </style>
  </head>
  <body>
    <div class ='row'>
      <div class='column left'>
        <h2> Breakfast</h2>
        <p><a href={b_inst}>{breakfast}</a><br><br>
       It will require:<br>
        {breakfastrecipe}<br><br></p>
      </div>
      <div class='column middle'>
        <h2> Lunch</h2>
        <p><a href={l_inst}>{lunch}</a><br><br>
            It will require:<br>
          {lunchrecipe}<br><br></p>
      </div>
      <div class='column right'>
        <h2> Dinner</h2>
        <p><a href={d_inst}>{dinner}</a><br><br>
            It will require:<br>
          {dinnerrecipe}<br><br></p>
      </div>
    </div>
  </body>
</html>
"""

# Turn these into plain/html MIMEText objects
part2 = MIMEText(html, "html")

# Add HTML/plain-text parts to MIMEMultipart message
# The email client will try to render the last part first
#message.attach(part1)
message.attach(part2)

#####END TEST MESSAGE#####

# Send the message via our own SMTP server.
server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
server.login("m.dendinger19@gmail.com", input("Type your password and press enter: "))
server.sendmail(
        sender_email, receiver_email, message.as_string()
    )
#server.send_message(msg)
server.quit()
# Out:
# Type your password and press enter: Xgkoutwzageyevil
# (221, b'2.0.0 closing connection t26sm12940119ilb.80 - gsmtp')
